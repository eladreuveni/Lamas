# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_mb_21 = pd.read_csv('../Data/H20211021/H20211021datamb.csv')

# %%
data_mb_21
# Out:
#       S_Seker  MisparMb  Hodesh_Hakira  Shnat_Hakira  Quarter   Weight  \
# 0        2021     28106              1          2021        1  383.712
# 1        2021     28107              1          2021        1  114.092
# 2        2021     28108              2          2021        1  195.015
# 3        2021     28109              1          2021        1  755.693
# 4        2021     28110              1          2021        1  527.768
# ...       ...       ...            ...           ...      ...      ...
# 6052     2021     53760              2          2022        4  182.102
# 6053     2021     53762              1          2022        4  278.277
# 6054     2021     58002              8          2021        3  604.582
# 6055     2021     58031              1          2022        4  429.712
# 6056     2021     65289             11          2021        4  500.224
#
#       Nefashot  NefeshStandartit  Mefarnesim  Nefashot0_4  ...   c34  c35  \
# 0            2              2.00           0          NaN  ...     0  305
# 1            1              1.25           0          NaN  ...    52  305
# 2            9              5.60           1          4.0  ...  2421    0
# 3            2              2.00           0          NaN  ...   186    0
# 4            2              2.00           1          NaN  ...   463    0
# ...        ...               ...         ...          ...  ...   ...  ...
# 6052         6              4.25           2          1.0  ...     0  612
# 6053         7              4.75           1          2.0  ...     0  613
# 6054         3              2.65           0          NaN  ...     0    0
# 6055         3              2.65           1          NaN  ...   681    0
# 6056         1              1.25           0          NaN  ...     0    0
#
#        c36   c37   c38    c39  RamatDatiyut  Sex_RMB  MaamadRMB  Religion
# 0     1416  1981   596   6796             1        2          3         1
# 1      520  1525  2831    900             1        2          3         1
# 2      510   447  2393    562             4        2          1         1
# 3      563     1   176      0             3        2          3         1
# 4     1403   112    46      0             2        1          1         1
# ...    ...   ...   ...    ...           ...      ...        ...       ...
# 6052  2103  2364  3088  21399             3        2          1         1
# 6053   833  1487    89    644             4        2          2         1
# 6054   141     0   617      0             2        1          3         3
# 6055   863   248   340     52             2        2          1         1
# 6056   597   148    89      0             1        2          3         1
#
# [6057 rows x 112 columns]

# %%
incomes = pd.DataFrame()

# %%
# Organize religions and religioness in lists
religions = ['Yehudi', 'Notzri', 'Muslemi', 'Druzi', 'Aher']
religion_mapping = {i: r for i, r in enumerate(religions, 1)}
religiosity_levels = ['Hiloni', 'Masorti', 'Dati', 'Haredi', 'Meorav', 'Aher']
religiosity_levels_mapping = {i: rl for i, rl in enumerate(religiosity_levels, 1)}
religion_mapping
# Out:
# {1: 'Yehudi', 2: 'Notzri', 3: 'Muslemi', 4: 'Druzi', 5: 'Aher'}

# %%
# fill incomes Data frame
incomes['mispar_mb'] = data_mb_21['MisparMb']
incomes['religion'] = data_mb_21['Religion']
incomes['religion_name'] = data_mb_21['Religion'].replace(religion_mapping)
incomes['religiosity_level'] = data_mb_21['RamatDatiyut']
incomes['nefashot'] = data_mb_21['Nefashot']
incomes['bruto_income'] = data_mb_21['i1Kaspit']
incomes['total_allowances'] = data_mb_21['i14']
incomes['allowances_as_percentage'] = (incomes['total_allowances'] / incomes['bruto_income']) * 100

# %%
incomes
# Out:
#       mispar_mb  religion  religiosity_level  bruto_income  total_allowances  \
# 0         28106         1                  1         34922              4467
# 1         28107         1                  1         12182             12182
# 2         28108         1                  4         13216              6046
# 3         28109         1                  3          3249              3086
# 4         28110         1                  2          3921              2051
# ...         ...       ...                ...           ...               ...
# 6052      53760         1                  3         75968              5373
# 6053      53762         1                  4         10941              4833
# 6054      58002         3                  2          4398              4398
# 6055      58031         1                  2          7712                 0
# 6056      65289         1                  1         16730              2815
#
#       allowances_as_percentage religion_name  nefashot
# 0                    12.791364        Yehudi         2
# 1                   100.000000        Yehudi         1
# 2                    45.747579        Yehudi         9
# 3                    94.983072        Yehudi         2
# 4                    52.308085        Yehudi         2
# ...                        ...           ...       ...
# 6052                  7.072715        Yehudi         6
# 6053                 44.173293        Yehudi         7
# 6054                100.000000       Muslemi         3
# 6055                  0.000000        Yehudi         3
# 6056                 16.826061        Yehudi         1
#
# [6057 rows x 8 columns]

# %%
# Calculate means of every religion
religions_means = incomes.groupby('religion_name').agg(
    {
        'nefashot': 'mean',
        'bruto_income': 'mean',
        'total_allowances': 'mean',
        'allowances_as_percentage': 'mean',
        'mispar_mb': 'count'
    }
).reset_index()

# Rename the 'mispar_mb' column to 'count' for clarity
religions_means.rename(columns={'mispar_mb': 'mb_count'}, inplace=True)

religions_means.sort_values('religion_name', ascending=False, inplace=True)

# Group by 'religion' and 'religiosity_level' and calculate the average and count for each group
grouped = incomes[incomes['religiosity_level'] < 5].groupby(['religion_name', 'religiosity_level']).agg(
    {
        'nefashot': 'mean',
        'bruto_income': 'mean',
        'total_allowances': 'mean',
        'allowances_as_percentage': 'mean',
        'mispar_mb': 'count'
    }
).reset_index()

# Rename the 'mispar_mb' column to 'count' for clarity
grouped.rename(columns={'mispar_mb': 'mb_count'}, inplace=True)

religions_means
# Out:
#   religion_name  nefashot  bruto_income  total_allowances  \
# 4        Yehudi  3.289350  23790.220933       3194.485644
# 3        Notzri  2.848780  15309.068293       3092.560976
# 2       Muslemi  4.094366  13458.626761       2852.870423
# 1         Druzi  3.789916  15879.226891       2192.756303
# 0          Aher  2.785714  19643.169643       2549.214286
#
#    allowances_as_percentage  mb_count
# 4                 25.717550      4911
# 3                 39.107358       205
# 2                 38.904452       710
# 1                 27.198984       119
# 0                 27.613418       112

# %%
# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Define colors for different religiosity levels
colors = ['b', 'g', 'r', 'c', 'm', 'y']

width = 0.1  # the width of the bars
multiplier = 0

religion_names = religions_means['religion_name'].unique()

# Iterate through each religion and plot bars for each religiosity level
for religion, color in zip(religions_means['religion_name'], colors):
    subset = grouped[grouped['religion_name'] == religion]
    offset = width * multiplier
    rects = ax.bar(offset + (subset['religiosity_level']/1.2), subset['allowances_as_percentage'].round(), width, color=color)
#     ax.bar_label(rects, padding=1)
    multiplier += 40
    # Define custom labels for each bar
    for i, rect in enumerate(rects):
        nef = round(subset.iloc[i]['nefashot'], 1)
        label = f'{int(rect.get_height())}%\n{nef}p'
        x = rect.get_x() + rect.get_width() / 2
        y = rect.get_height()
        ax.text(x, y, label, ha='center', va='bottom')
        rect.set_alpha(i/5 + 0.2)
                
# Set the x-axis labels to be religion names
ax.set_xticks([i*2 + 0.5 for i in range(len(religion_names))])
ax.set_xticklabels(religion_names, rotation=45, ha="right")
    
# Set labels and title
ax.set_xlabel('Religion')
ax.set_ylabel('Average Allowances as Percentage')
ax.set_title('Average Allowances as Percentage by Religion and Religiosity Level')

note = 'Note: As the line has less opacity,\nthe family is more religious'
ax.text(0.05, 0.97, note, transform=ax.transAxes, fontsize=10, verticalalignment='top', backgroundcolor='white')
# Out:
# Text(0.05, 0.97, 'Note: As the line has less opacity,\nthe family is more religious')

# %%
grouped
# Out:
#    religion_name  religiosity_level  nefashot  bruto_income  total_allowances  \
# 0           Aher                  1  2.731959  19495.618557       2436.855670
# 1           Aher                  2  3.500000  16033.500000      12773.500000
# 2           Aher                  3  4.500000  13295.000000        175.000000
# 3          Druzi                  1  3.923077  19999.871795       1879.282051
# 4          Druzi                  2  4.239130  15967.239130       2375.869565
# 5          Druzi                  3  2.666667  10714.083333       2027.583333
# 6        Muslemi                  1  3.743590  18028.051282       2130.692308
# 7        Muslemi                  2  4.370474  14131.582173       2616.103064
# 8        Muslemi                  3  3.762590  11801.133094       3364.064748
# 9        Muslemi                  4  2.000000   3750.000000       3750.000000
# 10        Notzri                  1  2.588235  15915.000000       2734.637255
# 11        Notzri                  2  2.951220  15036.743902       3460.597561
# 12        Notzri                  3  3.000000  11248.625000       5326.500000
# 13        Yehudi                  1  2.709490  26314.050145       3080.552010
# 14        Yehudi                  2  2.992647  22216.130515       3176.576287
# 15        Yehudi                  3  3.847856  23113.780083       2891.908714
# 16        Yehudi                  4  5.589091  16431.060000       3995.969091
#
#     allowances_as_percentage  mb_count
# 0                  28.476348        97
# 1                  83.168981         2
# 2                   2.376749         2
# 3                  14.227636        39
# 4                  29.715200        46
# 5                  39.097004        24
# 6                  32.129794        39
# 7                  32.506311       359
# 8                  49.082537       278
# 9                 100.000000         1
# 10                 33.837000       102
# 11                 42.920188        82
# 12                 63.916840         8
# 13                 23.958152      2413
# 14                 27.014389      1088
# 15                 22.737247       723
# 16                 35.436777       550
