# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Construct the file path using pathlib
file_path = Path('data/data_mb_all_years') / f'2021.csv'
csv = pd.read_csv(file_path)
csv
# Out:
#       S_Seker  MisparMb  Hodesh_Hakira  Shnat_Hakira  Quarter   Weight  \
# 0        2021     28106              1          2021        1  383.712
# 1        2021     28107              1          2021        1  114.092
# 2        2021     28108              2          2021        1  195.015
# 3        2021     28109              1          2021        1  755.693
# 4        2021     28110              1          2021        1  527.768
# ...       ...       ...            ...           ...      ...      ...
# 6052     2021     53760              2          2022        4  182.102
# 6053     2021     53762              1          2022        4  278.277
# 6054     2021     58002              8          2021        3  604.582
# 6055     2021     58031              1          2022        4  429.712
# 6056     2021     65289             11          2021        4  500.224
#
#       Nefashot  NefeshStandartit  Mefarnesim  Nefashot0_4  ...   c34  c35  \
# ...

# %%
df = csv[['MisparMb', 'NefeshStandartit', 'Weight', 'i1Kaspit', 'iInKind', 'Decile']]
df['s_income'] = (df['i1Kaspit'] + df['iInKind']) / df['NefeshStandartit']

# Calculate deciles using numpy's percentile function
deciles = np.percentile(df['s_income'], np.arange(0, 100, 10))
print(deciles)

# Creating a new column indicating the decile for each salary
df['salary_decile'] = pd.cut(df['salary'], bins=deciles, labels=decile_labels, include_lowest=True)

df[(df['s_income'] > 3070) & (df['s_income'] < 3090)].sort_values('s_income')
# Out:
# [    0.          3078.28705882  4188.48823529  5315.2
#   6530.16        7904.90566038  9298.55294118 11119.235
#  13535.68       17876.34117647]
# C:\Users\elad\AppData\Local\Temp\ipykernel_1752\3916537424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['standardized_income'] = (df['i1Kaspit'] + df['iInKind']) / df['NefeshStandartit']
#       MisparMb  NefeshStandartit    Weight  i1Kaspit  iInKind  Decile  \
# 1141     29249              2.00   798.856      3243     2899       2
# 3683     33200              3.75   346.518     11517        0       2
# 2773     31887              3.20   134.602      9828        0       2
# 527      28635              5.60   149.204     12670     4534       2
# ...
